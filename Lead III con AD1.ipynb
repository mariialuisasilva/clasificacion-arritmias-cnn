# %% [markdown]
# # Imports

# %%
import tensorflow as tf
import pandas as pd
import os
import cv2
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys



from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.initializers import HeNormal, GlorotNormal

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
from sklearn.metrics import f1_score, classification_report, roc_curve, auc, RocCurveDisplay

sys.path.append('./modelos/Lead III')
from utils import *  # Esto importará todas las funciones y variables definidas en utils.py

# %% [markdown]
# # Cargar los datos

# %%
# Cargar los CSV
rutaCSV = "../BD/ECGData_ScalogramImgSuavizadas_299_299_csv/"
train_df = pd.read_csv(rutaCSV + "ECGData_ScalogramImgSuavizadas_299_299_Train_stratified.csv")
val_df = pd.read_csv(rutaCSV + "ECGData_ScalogramImgSuavizadas_299_299_Val_stratified.csv")
test_df = pd.read_csv(rutaCSV + "ECGData_ScalogramImgSuavizadas_299_299_Test_stratified.csv")

# Contar instancias en cada conjunto
print(f"Entrenamiento: {len(train_df)} imágenes")
print(f"Validación: {len(val_df)} imágenes")
print(f"Prueba: {len(test_df)} imágenes")

# Separar los canales para cada conjunto
train_canales = separar_por_canales(train_df)
val_canales = separar_por_canales(val_df)
test_canales = separar_por_canales(test_df)

print("\n")

# Mostrar la cantidad de imágenes por canal para cada conjunto
print(f"Entrenamiento: {len(train_canales[CANAL-1])} instacias")
print(f"Validación: {len(val_canales[CANAL-1])} instacias")
print(f"Prueba: {len(test_canales[CANAL-1])} instacias")
# Out:
# Entrenamiento: 81360 imágenes
# Validación: 20316 imágenes
# Prueba: 25380 imágenes
#
#
# Entrenamiento: 6780 instacias
# Validación: 1693 instacias
# Prueba: 2115 instacias

# %% [markdown]
# # Estadísticas del conjunto de datos

# %%
# Graficar la distribución para cada conjunto
plot_class_distribution(train_canales[CANAL-1], 'Conjunto de entrenamiento')
plot_class_distribution(val_canales[CANAL-1], 'Conjunto de validación')
plot_class_distribution(test_canales[CANAL-1], 'Conjunto de prueba')

# %% [markdown]
# # Mostrar un ejemplo de cada clase

# %%
# Obtener las clases únicas
class_labels = train_canales[CANAL-1]['Label'].unique()

# Directorio donde se encuentran las imágenes
directorio = "../BD/"

# Crear una figura para mostrar 4 imágenes
plt.figure(figsize=(10, 5))

for i, label in enumerate(class_labels):
    # Obtener la primera imagen de esta clase
    sample_image_name = train_df[train_df['Label'] == label]['Filepath'].values[0]
    
    # Construir la ruta completa
    image_path = os.path.join(directorio, sample_image_name)
    
    # Leer y mostrar la imagen
    img = cv2.imread(image_path)  # Leer imagen
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convertir de BGR a RGB (para mostrar bien los colores)
    
    plt.subplot(1, 4, i + 1)
    plt.imshow(img)
    plt.title(label)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Conjunto de datos

# %% [markdown]
# ## Aumento de datos

# %%
# Se aplica aumento de datos en el conjunto de entrenamiento
train_datagen = ImageDataGenerator(
    rescale=1./255,  # Píxeles en el rango [0, 255] -> [0, 1]
    dtype='float32',  # Tipo de dato de las imágenes
    rotation_range=ROTACION_MAX_AD, # Rotación leve
                                    # Si va mal bajarla a 5-8 grados
    width_shift_range=DESPLAZAMIENTO_HORIZONTAL_AD, # Si va mal bajarlo a 5%
    height_shift_range=DESPLAZAMIENTO_VERTICAL_AD, # Si va mal bajarlo a 5%
    brightness_range=BRILLO_AD,  # Pequeñas variaciones de brillo
    # horizontal_flip=True  -> No se aplica porque los ECG son sensibles a la orientación
                            # Cambiaría completamente la señal
    zoom_range=ZOOM_MAX_AD, # zoom pequeño para preservar las características de la imagen (ondas ECG)
    fill_mode='nearest'     # Relleno de píxeles con el valor más cercano
                            # Se pone esta opción para evitar introducir información irrelevante en la
                            # imagen
)

# No se aplica aumento de datos en los conjuntos de validación y prueba (solo se reescalan los píxeles)
test_datagen = ImageDataGenerator(
    rescale=1./255,
    dtype='float32'
)
validation_datagen = ImageDataGenerator(
    rescale=1./255,
    dtype='float32'
)

# %% [markdown]
# ## Crear generadores de datos

# %%
# Generar una semilla aleatoria para mezclar los datos de entrenamiento y asegurar la reproducibilidad de
# los resultados
#seed_value = np.random.randint(0, 2**32, dtype='int64')  # Número aleatorio entre 0 y 2^32-1
seed_value = 3367708436  # Semilla fija para reproducibilidad
print(f"Semilla utilizada: {seed_value}")

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_canales[CANAL-1],
    directory=directorio,  
    x_col="Filepath",  # Nombre de la columna con las rutas de imágenes
    y_col="Label",  # Nombre de la columna con las etiquetas
    target_size=IMG_SIZE, # Tamaño al que se redimensionan las imágenes
                            # Inception-v3 requiere imágenes de 299x299
    batch_size=BATCH_SIZE_TRAIN, # mini-lotes de 8
    class_mode='categorical', # one-hot encoding
    shuffle=True,  # Mezclar las imágenes
    seed=seed_value
)

test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_canales[CANAL-1],
    directory=directorio,
    x_col="Filepath",
    y_col="Label",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE_TEST,
    class_mode='categorical',
    shuffle=False  # No mezclar las imágenes para evaluar el modelo
)

validation_generator = validation_datagen.flow_from_dataframe(
    dataframe=val_canales[CANAL-1],
    directory=directorio,  
    x_col="Filepath",
    y_col="Label",
    target_size=IMG_SIZE,
    batch_size=BATCH_SIZE_VAL,
    class_mode='categorical'
)
# Out:
# Semilla utilizada: 3367708436
# Found 6780 validated image filenames belonging to 4 classes.
# Found 2115 validated image filenames belonging to 4 classes.
# Found 1693 validated image filenames belonging to 4 classes.

# %% [markdown]
# ## Mostrar imágenes originales y aumentadas

# %%
# Como el generador produce imágenes aleatorias (shuffle=True), cada vez que se ejecute la función
# mostrará imágenes diferentes
mostrar_aumento_de_datos(train_generator, num_images=4)

# %% [markdown]
# # **Inception-v3**

# %% [markdown]
# # Construcción del modelo

# %% [markdown]
# ### Extracción de características
# En Inception-v3, el mapa de características que se extrae del último módulo de inception (Mixed_7c) tiene un tamaño de 8 × 8 × 2048. La aplicación de *average pooling* sobre este mapa de características da como resultado un vector de 1 × 1 × 2048 dimensiones, que se usa como vector de características.
#
# ### Clasificación
# Consiste en capas completamente conectadas y una función de activación softmax para clasificar los cuatro grupos de registros de ECG.
#
# Se generan valores de predicción en el rango de 0 a 1 para las cuatro etiquetas.

# %%
### EXTRACCIÓN DE CARACTERÍSTICAS ###

# Cargar el modelo base preentrenado
base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=IMG_SIZE + (3,))

# Seleccionar la última capa convolucional "Mixed_7c" como salida del extractor de características:
# Inception-v3 contiene múltiples módulos llamados "Mixed".
# Mixed_7c es la última capa convolucional de Inception-v3, justo antes de la parte de clasificación.
# Genera un mapa de características de tamaño 8x8x2048.
# Esta capa se utiliza para extraer características de las imágenes.
feature_extractor = base_model.get_layer('mixed10').output  # En tensorflow la última capa convolucional
                                                            # es "mixed10". La capa Mixed_7c en la
                                                            # arquitectura original de Inception-v3
                                                            # corresponde a mixed10 en TensorFlow.

# Aplicar Average Pooling para reducir las dimensiones a 1x1x2048
x = GlobalAveragePooling2D()(feature_extractor)



### CLASIFICACIÓN ###

# x = Dropout(0.3)(x)  # Añadir Dropout aquí si hubiera sobreajuste

# Capa completamente conectada (fully connected layer)
# Este tipo de capas es como un "cerebro final" que toma las características extraídas por la red y las
# convierte en predicciones finales con la función de activación ReLU.
x = Dense(NUM_NEURONAS_DENSE1, activation='relu', kernel_initializer=HeNormal())(x)
# Se usa ReLU como función de activación porque ayuda a la red a aprender representaciones no
# lineales
# Se usa HeNormal() como inicializador de pesos porque es adecuado para capas con ReLU.

# Cada vez que agregamos una capa densa grande, las activaciones pueden crecer demasiado o distribuirse de
# manera inestable. BatchNormalization() ayuda a normalizarlas antes de la siguiente transformación no
# lineal (ReLU).
x = BatchNormalization()(x)

# Se desactivan aleatoriamente ciertas neuronas de la capa anterior para evitar que la red dependa
# demasiado de ellas y así prevenir el sobreajuste. En cada etapa del entrenamiento, se apagan diferentes
# neuronas, lo que ayuda a la red a generalizar mejor.
x = Dropout(DROPOUT1)(x) # Ajustar según el rendimiento en el conjunto de validación
                    # Para >= 512 neuronas se recomienda un dropout de 0.5, ya que el riesgo de sobreajuste
                    # es alto

### ¿Por qué BatchNormalization() antes de Dropout()?: ###
# Si ponemos Dropout antes de BatchNormalization, estaríamos normalizando activaciones con valores
# aleatorios eliminados, es decir, con ceros artificiales añadidos por Dropout, no por la capa Dense.

x = Dense(NUM_NEURONAS_DENSE2, activation='relu', kernel_initializer=HeNormal())(x)
x = BatchNormalization()(x)
x = Dropout(DROPOUT2)(x) # Conforme vamos bajando el número de neuronas, podemos reducir el dropout

x = Dense(NUM_NEURONAS_DENSE3, activation='relu', kernel_initializer=HeNormal())(x)
# Aquí no puse BatchNormalization(), porque es una capa más pequeña y ya ha pasado por suficiente
# normalización antes.
x = Dropout(DROPOUT3)(x)

# Capa de salida (función de activación softmax)
output_layer = Dense(NUM_CLASES, activation='softmax', kernel_initializer=GlorotNormal())(x)

# Definir el modelo final
model = Model(inputs=base_model.input, outputs=output_layer)

# Mostrar el resumen del modelo
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 80)   5120        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 80)  240         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 80)   0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 71, 71, 192)  138240      ['activation_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 71, 71, 192)  576        ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 71, 71, 192)  0           ['batch_normalization_4[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_4[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 35, 35, 48)   9216        ['max_pooling2d_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 35, 35, 48)  144         ['conv2d_6[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 35, 35, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 35, 35, 48)   0           ['batch_normalization_6[0][0]']
#
#  activation_9 (Activation)      (None, 35, 35, 96)   0           ['batch_normalization_9[0][0]']
#
#  average_pooling2d (AveragePool  (None, 35, 35, 192)  0          ['max_pooling2d_1[0][0]']
#  ing2D)
#
#  conv2d_5 (Conv2D)              (None, 35, 35, 64)   12288       ['max_pooling2d_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 64)   76800       ['activation_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_9[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 32)   6144        ['average_pooling2d[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 35, 35, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_10 (BatchN  (None, 35, 35, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 35, 35, 32)  96          ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_5 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_5[0][0]']
#
#  activation_7 (Activation)      (None, 35, 35, 64)   0           ['batch_normalization_7[0][0]']
#
#  activation_10 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 35, 35, 32)   0           ['batch_normalization_11[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_5[0][0]',
#                                                                   'activation_7[0][0]',
#                                                                   'activation_10[0][0]',
#                                                                   'activation_11[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 35, 35, 64)  192         ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_15[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 35, 35, 48)  144         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 35, 35, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_16[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  oling2D)
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_13[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 35, 35, 64)   16384       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 35, 35, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 35, 35, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 35, 35, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 35, 35, 64)  192         ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_14 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_14[0][0]']
#
#  activation_17 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_18[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_12[0][0]',
#                                                                   'activation_14[0][0]',
#                                                                   'activation_17[0][0]',
#                                                                   'activation_18[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 35, 35, 64)  192         ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_22[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 35, 35, 48)  144         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 35, 35, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 35, 35, 48)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_23[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  oling2D)
#
#  conv2d_19 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 35, 35, 64)   76800       ['activation_20[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 35, 35, 96)   82944       ['activation_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 35, 35, 64)   18432       ['average_pooling2d_2[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 35, 35, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_21 (BatchN  (None, 35, 35, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 35, 35, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 35, 35, 64)  192         ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_21 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_21[0][0]']
#
#  activation_24 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_25[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_19[0][0]',
#                                                                   'activation_21[0][0]',
#                                                                   'activation_24[0][0]',
#                                                                   'activation_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 35, 35, 64)  192         ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 35, 35, 64)   0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 35, 35, 96)   55296       ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 35, 35, 96)  288         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 35, 35, 96)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 17, 17, 96)   82944       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 17, 17, 384)  1152       ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 17, 17, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 17, 17, 384)  0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 17, 17, 96)   0           ['batch_normalization_29[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_26[0][0]',
#                                                                   'activation_29[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 17, 17, 128)  384        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 17, 17, 128)  384        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_35[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 17, 17, 128)  384        ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 17, 17, 128)  384        ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_31[0][0]']
#
#  activation_36 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_31[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 17, 17, 128)  114688      ['activation_36[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 17, 17, 128)  384        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 17, 17, 128)  384        ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_32[0][0]']
#
#  activation_37 (Activation)     (None, 17, 17, 128)  0           ['batch_normalization_37[0][0]']
#
#  average_pooling2d_3 (AveragePo  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  oling2D)
#
#  conv2d_30 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_32[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 17, 17, 192)  172032      ['activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_3[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 17, 17, 192)  576        ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 17, 17, 192)  576        ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 17, 17, 192)  576        ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 17, 17, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_30[0][0]']
#
#  activation_33 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_33[0][0]']
#
#  activation_38 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_38[0][0]']
#
#  activation_39 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_39[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_30[0][0]',
#                                                                   'activation_33[0][0]',
#                                                                   'activation_38[0][0]',
#                                                                   'activation_39[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 17, 17, 160)  480        ['conv2d_44[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 17, 17, 160)  480        ['conv2d_45[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_45[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 17, 17, 160)  480        ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 17, 17, 160)  480        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_41[0][0]']
#
#  activation_46 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_41[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_46[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 17, 17, 160)  480        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_47 (BatchN  (None, 17, 17, 160)  480        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_42[0][0]']
#
#  activation_47 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_47[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  oling2D)
#
#  conv2d_40 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_42[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_47[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_4[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 17, 17, 192)  576        ['conv2d_40[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 17, 17, 192)  576        ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_48 (BatchN  (None, 17, 17, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 17, 17, 192)  576        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_40[0][0]']
#
#  activation_43 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_43[0][0]']
#
#  activation_48 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_48[0][0]']
#
#  activation_49 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_49[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_40[0][0]',
#                                                                   'activation_43[0][0]',
#                                                                   'activation_48[0][0]',
#                                                                   'activation_49[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 17, 17, 160)  480        ['conv2d_54[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 17, 17, 160)  480        ['conv2d_55[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_55[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_55[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 17, 17, 160)  480        ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 17, 17, 160)  480        ['conv2d_56[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_51[0][0]']
#
#  activation_56 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_56[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 17, 17, 160)  179200      ['activation_56[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 17, 17, 160)  480        ['conv2d_52[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 17, 17, 160)  480        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_52[0][0]']
#
#  activation_57 (Activation)     (None, 17, 17, 160)  0           ['batch_normalization_57[0][0]']
#
#  average_pooling2d_5 (AveragePo  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  oling2D)
#
#  conv2d_50 (Conv2D)             (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_52[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 17, 17, 192)  215040      ['activation_57[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 17, 17, 192)  147456      ['average_pooling2d_5[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 17, 17, 192)  576        ['conv2d_50[0][0]']
#  ormalization)
#
#  batch_normalization_53 (BatchN  (None, 17, 17, 192)  576        ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 17, 17, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 17, 17, 192)  576        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_50[0][0]']
#
#  activation_53 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_53[0][0]']
#
#  activation_58 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_58[0][0]']
#
#  activation_59 (Activation)     (None, 17, 17, 192)  0           ['batch_normalization_59[0][0]']
# ...
#
#  conv2d_78 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_77[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_81[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_78[0][0]']
#  ormalization)
#
#  batch_normalization_79 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_79[0][0]']
#  ormalization)
#
#  batch_normalization_82 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_82[0][0]']
#  ormalization)
#
#  batch_normalization_83 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_83[0][0]']
#  ormalization)
#
#  conv2d_84 (Conv2D)             (None, 8, 8, 192)    245760      ['average_pooling2d_7[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 8, 8, 320)   960         ['conv2d_76[0][0]']
#  ormalization)
#
#  activation_78 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_78[0][0]']
#
#  activation_79 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_79[0][0]']
#
#  activation_82 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_82[0][0]']
#
#  activation_83 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_83[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 8, 8, 192)   576         ['conv2d_84[0][0]']
#  ormalization)
#
#  activation_76 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_76[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_78[0][0]',
#                                                                   'activation_79[0][0]']
#
#  concatenate (Concatenate)      (None, 8, 8, 768)    0           ['activation_82[0][0]',
#                                                                   'activation_83[0][0]']
#
#  activation_84 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_84[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_76[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate[0][0]',
#                                                                   'activation_84[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 8, 8, 448)   1344        ['conv2d_89[0][0]']
#  ormalization)
#
#  activation_89 (Activation)     (None, 8, 8, 448)    0           ['batch_normalization_89[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 8, 8, 384)    1548288     ['activation_89[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_86[0][0]']
#  ormalization)
#
#  batch_normalization_90 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_90[0][0]']
#  ormalization)
#
#  activation_86 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_86[0][0]']
#
#  activation_90 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_90[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_86[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 8, 8, 384)    442368      ['activation_90[0][0]']
#
#  average_pooling2d_8 (AveragePo  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  oling2D)
#
#  conv2d_85 (Conv2D)             (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_87[0][0]']
#  ormalization)
#
#  batch_normalization_88 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_88[0][0]']
#  ormalization)
#
#  batch_normalization_91 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_91[0][0]']
#  ormalization)
#
#  batch_normalization_92 (BatchN  (None, 8, 8, 384)   1152        ['conv2d_92[0][0]']
#  ormalization)
#
#  conv2d_93 (Conv2D)             (None, 8, 8, 192)    393216      ['average_pooling2d_8[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 8, 8, 320)   960         ['conv2d_85[0][0]']
#  ormalization)
#
#  activation_87 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_87[0][0]']
#
#  activation_88 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_88[0][0]']
#
#  activation_91 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_91[0][0]']
#
#  activation_92 (Activation)     (None, 8, 8, 384)    0           ['batch_normalization_92[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 8, 8, 192)   576         ['conv2d_93[0][0]']
#  ormalization)
#
#  activation_85 (Activation)     (None, 8, 8, 320)    0           ['batch_normalization_85[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_87[0][0]',
#                                                                   'activation_88[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 8, 8, 768)    0           ['activation_91[0][0]',
#                                                                   'activation_92[0][0]']
#
#  activation_93 (Activation)     (None, 8, 8, 192)    0           ['batch_normalization_93[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_85[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'activation_93[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['mixed10[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 512)          1049088     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  batch_normalization_94 (BatchN  (None, 512)         2048        ['dense[0][0]']
#  ormalization)
#
#  dropout (Dropout)              (None, 512)          0           ['batch_normalization_94[0][0]']
#
#  dense_1 (Dense)                (None, 256)          131328      ['dropout[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 256)         1024        ['dense_1[0][0]']
#  ormalization)
#
#  dropout_1 (Dropout)            (None, 256)          0           ['batch_normalization_95[0][0]']
#
#  dense_2 (Dense)                (None, 128)          32896       ['dropout_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 128)          0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 4)            516         ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 23,019,684
# Trainable params: 22,983,716
# Non-trainable params: 35,968
# __________________________________________________________________________________________________

# %% [markdown]
# ## Entrenamiento

# %% [markdown]
# ### Métricas

# %%
METRICS = [
      tf.keras.metrics.BinaryAccuracy(name='accuracy'),
      tf.keras.metrics.Precision(name='precision'),
      tf.keras.metrics.Recall(name='recall'), # sensibilidad
      tf.keras.metrics.AUC(name='auc'),
      #f1_score
]

# %% [markdown]
# ### Fase 1: Entrenar solo la nueva parte de clasificación

# %%
# Freezing Layers: Congelar todas las capas del modelo base
# Se usa un modelo preentrenado (transfer learning)
base_model.trainable = False

model.compile(optimizer=Adam(learning_rate=LEARNING_RATE, beta_1=BETA_1, beta_2=BETA_2),
              loss='categorical_crossentropy', # Función de pérdida: cross-entropy
              metrics=METRICS)
# Keras interpreta que es un problema de clasificación multiclase porque la función de pérdida es
# categorical_crossentropy. Con esto, las métricas de precisión, recall y AUC se calculan para cada clase
# y se hace un promedio ponderado (se tiene en cuenta las instancias de cada clase) para obtener un valor
# global.

early_stopping_phase1 = EarlyStopping(monitor='val_loss',
                                      patience=PATIENCE_FASE1,
                                      restore_best_weights=True
                                      )

# Entrenamiento inicial (solo capas de clasificación)
history_phase1 = model.fit(train_generator,
                           validation_data=validation_generator,
                           epochs=EPOCH,
                           callbacks=[early_stopping_phase1]
                           )

# Guardar el modelo incluyendo el valor de seed_value en el nombre del archivo
model.save(f'./modelos/Lead III/modelo_phase1_{seed_value}.keras')
# Out:
# Epoch 1/500
# 848/848 [==============================] - 164s 185ms/step - loss: 1.3284 - accuracy: 0.7859 - precision: 0.5821 - recall: 0.5086 - auc: 0.7904 - val_loss: 0.5951 - val_accuracy: 0.9051 - val_precision: 0.8285 - val_recall: 0.7820 - val_auc: 0.9409
# Epoch 2/500
# 848/848 [==============================] - 109s 129ms/step - loss: 1.0001 - accuracy: 0.8334 - precision: 0.6822 - recall: 0.6248 - auc: 0.8692 - val_loss: 0.6015 - val_accuracy: 0.9002 - val_precision: 0.8125 - val_recall: 0.7809 - val_auc: 0.9428
# Epoch 3/500
# 848/848 [==============================] - 106s 124ms/step - loss: 0.9033 - accuracy: 0.8496 - precision: 0.7158 - recall: 0.6609 - auc: 0.8887 - val_loss: 0.5167 - val_accuracy: 0.9127 - val_precision: 0.8470 - val_recall: 0.7944 - val_auc: 0.9525
# Epoch 4/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.8387 - accuracy: 0.8560 - precision: 0.7319 - recall: 0.6693 - auc: 0.8989 - val_loss: 0.4860 - val_accuracy: 0.9191 - val_precision: 0.8541 - val_recall: 0.8157 - val_auc: 0.9579
# Epoch 5/500
# 848/848 [==============================] - 106s 124ms/step - loss: 0.7830 - accuracy: 0.8659 - precision: 0.7503 - recall: 0.6950 - auc: 0.9091 - val_loss: 0.4836 - val_accuracy: 0.9186 - val_precision: 0.8520 - val_recall: 0.8163 - val_auc: 0.9581
# Epoch 6/500
# 848/848 [==============================] - 108s 128ms/step - loss: 0.7693 - accuracy: 0.8672 - precision: 0.7538 - recall: 0.6960 - auc: 0.9106 - val_loss: 0.4650 - val_accuracy: 0.9214 - val_precision: 0.8590 - val_recall: 0.8204 - val_auc: 0.9607
# Epoch 7/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.7604 - accuracy: 0.8677 - precision: 0.7542 - recall: 0.6987 - auc: 0.9116 - val_loss: 0.4348 - val_accuracy: 0.9282 - val_precision: 0.8732 - val_recall: 0.8340 - val_auc: 0.9644
# Epoch 8/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.7079 - accuracy: 0.8767 - precision: 0.7742 - recall: 0.7156 - auc: 0.9200 - val_loss: 0.4553 - val_accuracy: 0.9232 - val_precision: 0.8696 - val_recall: 0.8151 - val_auc: 0.9621
# Epoch 9/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.7108 - accuracy: 0.8740 - precision: 0.7701 - recall: 0.7071 - auc: 0.9185 - val_loss: 0.4571 - val_accuracy: 0.9234 - val_precision: 0.8678 - val_recall: 0.8181 - val_auc: 0.9611
# Epoch 10/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.6662 - accuracy: 0.8807 - precision: 0.7830 - recall: 0.7232 - auc: 0.9273 - val_loss: 0.4229 - val_accuracy: 0.9285 - val_precision: 0.8809 - val_recall: 0.8258 - val_auc: 0.9665
# Epoch 11/500
# 848/848 [==============================] - 108s 127ms/step - loss: 0.6682 - accuracy: 0.8809 - precision: 0.7834 - recall: 0.7235 - auc: 0.9262 - val_loss: 0.4381 - val_accuracy: 0.9266 - val_precision: 0.8761 - val_recall: 0.8228 - val_auc: 0.9642
# Epoch 12/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.6336 - accuracy: 0.8868 - precision: 0.7962 - recall: 0.7354 - auc: 0.9327 - val_loss: 0.4238 - val_accuracy: 0.9300 - val_precision: 0.8826 - val_recall: 0.8305 - val_auc: 0.9672
# Epoch 13/500
# 848/848 [==============================] - 108s 128ms/step - loss: 0.6417 - accuracy: 0.8854 - precision: 0.7952 - recall: 0.7296 - auc: 0.9307 - val_loss: 0.4432 - val_accuracy: 0.9228 - val_precision: 0.8638 - val_recall: 0.8204 - val_auc: 0.9640
# Epoch 14/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.6270 - accuracy: 0.8883 - precision: 0.7976 - recall: 0.7412 - auc: 0.9336 - val_loss: 0.4057 - val_accuracy: 0.9352 - val_precision: 0.8929 - val_recall: 0.8417 - val_auc: 0.9706
# Epoch 15/500
# 848/848 [==============================] - 107s 127ms/step - loss: 0.6116 - accuracy: 0.8925 - precision: 0.8073 - recall: 0.7488 - auc: 0.9361 - val_loss: 0.4213 - val_accuracy: 0.9285 - val_precision: 0.8785 - val_recall: 0.8287 - val_auc: 0.9672
# Epoch 16/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.5982 - accuracy: 0.8950 - precision: 0.8125 - recall: 0.7541 - auc: 0.9386 - val_loss: 0.3990 - val_accuracy: 0.9353 - val_precision: 0.8944 - val_recall: 0.8405 - val_auc: 0.9709
# Epoch 17/500
# 848/848 [==============================] - 108s 127ms/step - loss: 0.5839 - accuracy: 0.8945 - precision: 0.8108 - recall: 0.7540 - auc: 0.9410 - val_loss: 0.4012 - val_accuracy: 0.9328 - val_precision: 0.8888 - val_recall: 0.8358 - val_auc: 0.9708
# Epoch 18/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.5970 - accuracy: 0.8941 - precision: 0.8124 - recall: 0.7497 - auc: 0.9392 - val_loss: 0.4182 - val_accuracy: 0.9240 - val_precision: 0.8649 - val_recall: 0.8246 - val_auc: 0.9676
# Epoch 19/500
# 848/848 [==============================] - 108s 128ms/step - loss: 0.5701 - accuracy: 0.8950 - precision: 0.8111 - recall: 0.7562 - auc: 0.9433 - val_loss: 0.3959 - val_accuracy: 0.9377 - val_precision: 0.8955 - val_recall: 0.8500 - val_auc: 0.9708
# Epoch 20/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.5881 - accuracy: 0.8964 - precision: 0.8145 - recall: 0.7584 - auc: 0.9406 - val_loss: 0.3970 - val_accuracy: 0.9324 - val_precision: 0.8833 - val_recall: 0.8405 - val_auc: 0.9707
# Epoch 21/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.5688 - accuracy: 0.8959 - precision: 0.8166 - recall: 0.7528 - auc: 0.9432 - val_loss: 0.3819 - val_accuracy: 0.9377 - val_precision: 0.8925 - val_recall: 0.8535 - val_auc: 0.9725
# Epoch 22/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.5681 - accuracy: 0.8992 - precision: 0.8213 - recall: 0.7628 - auc: 0.9438 - val_loss: 0.3776 - val_accuracy: 0.9358 - val_precision: 0.8897 - val_recall: 0.8482 - val_auc: 0.9738
# Epoch 23/500
# 848/848 [==============================] - 108s 128ms/step - loss: 0.5434 - accuracy: 0.9046 - precision: 0.8303 - recall: 0.7773 - auc: 0.9483 - val_loss: 0.3873 - val_accuracy: 0.9322 - val_precision: 0.8818 - val_recall: 0.8417 - val_auc: 0.9716
# Epoch 24/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.5388 - accuracy: 0.9027 - precision: 0.8279 - recall: 0.7712 - auc: 0.9492 - val_loss: 0.3940 - val_accuracy: 0.9304 - val_precision: 0.8804 - val_recall: 0.8352 - val_auc: 0.9710
# Epoch 25/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.5446 - accuracy: 0.9039 - precision: 0.8283 - recall: 0.7764 - auc: 0.9483 - val_loss: 0.3733 - val_accuracy: 0.9377 - val_precision: 0.8940 - val_recall: 0.8517 - val_auc: 0.9736
# Epoch 26/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.5347 - accuracy: 0.9034 - precision: 0.8284 - recall: 0.7739 - auc: 0.9495 - val_loss: 0.3621 - val_accuracy: 0.9412 - val_precision: 0.8965 - val_recall: 0.8647 - val_auc: 0.9753
# Epoch 27/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.5402 - accuracy: 0.9038 - precision: 0.8294 - recall: 0.7745 - auc: 0.9489 - val_loss: 0.3840 - val_accuracy: 0.9319 - val_precision: 0.8798 - val_recall: 0.8429 - val_auc: 0.9728
# Epoch 28/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.5441 - accuracy: 0.9033 - precision: 0.8287 - recall: 0.7729 - auc: 0.9479 - val_loss: 0.3776 - val_accuracy: 0.9353 - val_precision: 0.8876 - val_recall: 0.8488 - val_auc: 0.9730
# Epoch 29/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.5423 - accuracy: 0.9027 - precision: 0.8273 - recall: 0.7717 - auc: 0.9483 - val_loss: 0.3837 - val_accuracy: 0.9321 - val_precision: 0.8789 - val_recall: 0.8447 - val_auc: 0.9723
# Epoch 30/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.5261 - accuracy: 0.9066 - precision: 0.8357 - recall: 0.7796 - auc: 0.9509 - val_loss: 0.3671 - val_accuracy: 0.9367 - val_precision: 0.8882 - val_recall: 0.8541 - val_auc: 0.9748
# Epoch 31/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.5287 - accuracy: 0.9066 - precision: 0.8357 - recall: 0.7796 - auc: 0.9504 - val_loss: 0.3797 - val_accuracy: 0.9330 - val_precision: 0.8789 - val_recall: 0.8488 - val_auc: 0.9735
# Epoch 32/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.5351 - accuracy: 0.9046 - precision: 0.8290 - recall: 0.7792 - auc: 0.9493 - val_loss: 0.3616 - val_accuracy: 0.9386 - val_precision: 0.8920 - val_recall: 0.8582 - val_auc: 0.9755
# Epoch 33/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.5287 - accuracy: 0.9060 - precision: 0.8324 - recall: 0.7814 - auc: 0.9505 - val_loss: 0.3694 - val_accuracy: 0.9377 - val_precision: 0.8925 - val_recall: 0.8535 - val_auc: 0.9751
# Epoch 34/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.5116 - accuracy: 0.9105 - precision: 0.8418 - recall: 0.7906 - auc: 0.9531 - val_loss: 0.3659 - val_accuracy: 0.9361 - val_precision: 0.8860 - val_recall: 0.8541 - val_auc: 0.9747
# Epoch 35/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.5172 - accuracy: 0.9064 - precision: 0.8336 - recall: 0.7817 - auc: 0.9523 - val_loss: 0.3675 - val_accuracy: 0.9350 - val_precision: 0.8841 - val_recall: 0.8517 - val_auc: 0.9743
# Epoch 36/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.5187 - accuracy: 0.9045 - precision: 0.8279 - recall: 0.7804 - auc: 0.9523 - val_loss: 0.3589 - val_accuracy: 0.9372 - val_precision: 0.8885 - val_recall: 0.8565 - val_auc: 0.9758
# Epoch 37/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.5148 - accuracy: 0.9080 - precision: 0.8362 - recall: 0.7860 - auc: 0.9530 - val_loss: 0.3814 - val_accuracy: 0.9319 - val_precision: 0.8788 - val_recall: 0.8441 - val_auc: 0.9730
# Epoch 38/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.5133 - accuracy: 0.9096 - precision: 0.8392 - recall: 0.7895 - auc: 0.9531 - val_loss: 0.3624 - val_accuracy: 0.9426 - val_precision: 0.9010 - val_recall: 0.8653 - val_auc: 0.9755
# Epoch 39/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.5127 - accuracy: 0.9103 - precision: 0.8397 - recall: 0.7926 - auc: 0.9527 - val_loss: 0.3603 - val_accuracy: 0.9408 - val_precision: 0.8963 - val_recall: 0.8630 - val_auc: 0.9756
# Epoch 40/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.5012 - accuracy: 0.9096 - precision: 0.8385 - recall: 0.7906 - auc: 0.9553 - val_loss: 0.3532 - val_accuracy: 0.9424 - val_precision: 0.9014 - val_recall: 0.8641 - val_auc: 0.9771
# Epoch 41/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4984 - accuracy: 0.9108 - precision: 0.8410 - recall: 0.7934 - auc: 0.9554 - val_loss: 0.3544 - val_accuracy: 0.9409 - val_precision: 0.8954 - val_recall: 0.8647 - val_auc: 0.9762
# Epoch 42/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.5035 - accuracy: 0.9128 - precision: 0.8453 - recall: 0.7969 - auc: 0.9547 - val_loss: 0.3541 - val_accuracy: 0.9411 - val_precision: 0.8974 - val_recall: 0.8630 - val_auc: 0.9762
# Epoch 43/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4925 - accuracy: 0.9133 - precision: 0.8467 - recall: 0.7975 - auc: 0.9565 - val_loss: 0.3527 - val_accuracy: 0.9403 - val_precision: 0.8947 - val_recall: 0.8630 - val_auc: 0.9762
# Epoch 44/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4976 - accuracy: 0.9118 - precision: 0.8430 - recall: 0.7951 - auc: 0.9554 - val_loss: 0.3405 - val_accuracy: 0.9439 - val_precision: 0.9005 - val_recall: 0.8718 - val_auc: 0.9776
# Epoch 45/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.5011 - accuracy: 0.9116 - precision: 0.8416 - recall: 0.7962 - auc: 0.9552 - val_loss: 0.3431 - val_accuracy: 0.9427 - val_precision: 0.8991 - val_recall: 0.8683 - val_auc: 0.9783
# Epoch 46/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.5019 - accuracy: 0.9089 - precision: 0.8384 - recall: 0.7875 - auc: 0.9550 - val_loss: 0.3540 - val_accuracy: 0.9440 - val_precision: 0.9026 - val_recall: 0.8701 - val_auc: 0.9773
# Epoch 47/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4929 - accuracy: 0.9127 - precision: 0.8446 - recall: 0.7975 - auc: 0.9565 - val_loss: 0.3714 - val_accuracy: 0.9393 - val_precision: 0.8923 - val_recall: 0.8612 - val_auc: 0.9742
# Epoch 48/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4863 - accuracy: 0.9143 - precision: 0.8472 - recall: 0.8016 - auc: 0.9578 - val_loss: 0.3432 - val_accuracy: 0.9420 - val_precision: 0.8959 - val_recall: 0.8689 - val_auc: 0.9773
# Epoch 49/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.5016 - accuracy: 0.9118 - precision: 0.8406 - recall: 0.7987 - auc: 0.9547 - val_loss: 0.3432 - val_accuracy: 0.9402 - val_precision: 0.8908 - val_recall: 0.8671 - val_auc: 0.9775
# Epoch 50/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4908 - accuracy: 0.9143 - precision: 0.8481 - recall: 0.8007 - auc: 0.9568 - val_loss: 0.3548 - val_accuracy: 0.9408 - val_precision: 0.8934 - val_recall: 0.8665 - val_auc: 0.9759
# Epoch 51/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.5052 - accuracy: 0.9126 - precision: 0.8440 - recall: 0.7981 - auc: 0.9542 - val_loss: 0.3454 - val_accuracy: 0.9445 - val_precision: 0.9052 - val_recall: 0.8689 - val_auc: 0.9774
# Epoch 52/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4847 - accuracy: 0.9146 - precision: 0.8462 - recall: 0.8047 - auc: 0.9576 - val_loss: 0.3460 - val_accuracy: 0.9437 - val_precision: 0.8985 - val_recall: 0.8736 - val_auc: 0.9771
# Epoch 53/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.4943 - accuracy: 0.9128 - precision: 0.8456 - recall: 0.7965 - auc: 0.9561 - val_loss: 0.3503 - val_accuracy: 0.9384 - val_precision: 0.8914 - val_recall: 0.8582 - val_auc: 0.9774
# Epoch 54/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.4831 - accuracy: 0.9167 - precision: 0.8525 - recall: 0.8065 - auc: 0.9580 - val_loss: 0.3561 - val_accuracy: 0.9399 - val_precision: 0.8945 - val_recall: 0.8612 - val_auc: 0.9759
# Epoch 55/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4847 - accuracy: 0.9137 - precision: 0.8451 - recall: 0.8016 - auc: 0.9577 - val_loss: 0.3493 - val_accuracy: 0.9409 - val_precision: 0.8964 - val_recall: 0.8636 - val_auc: 0.9773
# Epoch 56/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4781 - accuracy: 0.9152 - precision: 0.8506 - recall: 0.8013 - auc: 0.9588 - val_loss: 0.3543 - val_accuracy: 0.9409 - val_precision: 0.8974 - val_recall: 0.8624 - val_auc: 0.9767
# Epoch 57/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4817 - accuracy: 0.9136 - precision: 0.8459 - recall: 0.8000 - auc: 0.9583 - val_loss: 0.3476 - val_accuracy: 0.9439 - val_precision: 0.9005 - val_recall: 0.8718 - val_auc: 0.9770
# Epoch 58/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4874 - accuracy: 0.9139 - precision: 0.8466 - recall: 0.8009 - auc: 0.9572 - val_loss: 0.3659 - val_accuracy: 0.9350 - val_precision: 0.8822 - val_recall: 0.8541 - val_auc: 0.9746
# Epoch 59/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4781 - accuracy: 0.9162 - precision: 0.8511 - recall: 0.8059 - auc: 0.9587 - val_loss: 0.3465 - val_accuracy: 0.9440 - val_precision: 0.9016 - val_recall: 0.8712 - val_auc: 0.9767
# Epoch 60/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4698 - accuracy: 0.9169 - precision: 0.8504 - recall: 0.8099 - auc: 0.9599 - val_loss: 0.3427 - val_accuracy: 0.9446 - val_precision: 0.8989 - val_recall: 0.8771 - val_auc: 0.9771
# Epoch 61/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4758 - accuracy: 0.9146 - precision: 0.8461 - recall: 0.8046 - auc: 0.9592 - val_loss: 0.3502 - val_accuracy: 0.9451 - val_precision: 0.9040 - val_recall: 0.8730 - val_auc: 0.9762
# Epoch 62/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4676 - accuracy: 0.9175 - precision: 0.8519 - recall: 0.8111 - auc: 0.9606 - val_loss: 0.3464 - val_accuracy: 0.9395 - val_precision: 0.8914 - val_recall: 0.8630 - val_auc: 0.9772
# Epoch 63/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4891 - accuracy: 0.9136 - precision: 0.8445 - recall: 0.8021 - auc: 0.9570 - val_loss: 0.3350 - val_accuracy: 0.9458 - val_precision: 0.9023 - val_recall: 0.8783 - val_auc: 0.9787
# Epoch 64/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4616 - accuracy: 0.9177 - precision: 0.8526 - recall: 0.8108 - auc: 0.9614 - val_loss: 0.3348 - val_accuracy: 0.9436 - val_precision: 0.8970 - val_recall: 0.8748 - val_auc: 0.9781
# Epoch 65/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4910 - accuracy: 0.9118 - precision: 0.8420 - recall: 0.7968 - auc: 0.9567 - val_loss: 0.3526 - val_accuracy: 0.9420 - val_precision: 0.8954 - val_recall: 0.8695 - val_auc: 0.9754
# Epoch 66/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4697 - accuracy: 0.9160 - precision: 0.8490 - recall: 0.8075 - auc: 0.9601 - val_loss: 0.3379 - val_accuracy: 0.9452 - val_precision: 0.9021 - val_recall: 0.8760 - val_auc: 0.9780
# Epoch 67/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4824 - accuracy: 0.9154 - precision: 0.8468 - recall: 0.8077 - auc: 0.9579 - val_loss: 0.3350 - val_accuracy: 0.9442 - val_precision: 0.9016 - val_recall: 0.8718 - val_auc: 0.9788
# Epoch 68/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4819 - accuracy: 0.9149 - precision: 0.8484 - recall: 0.8031 - auc: 0.9581 - val_loss: 0.3420 - val_accuracy: 0.9415 - val_precision: 0.8947 - val_recall: 0.8683 - val_auc: 0.9779
# Epoch 69/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4856 - accuracy: 0.9127 - precision: 0.8440 - recall: 0.7982 - auc: 0.9572 - val_loss: 0.3630 - val_accuracy: 0.9362 - val_precision: 0.8852 - val_recall: 0.8559 - val_auc: 0.9752
# Epoch 70/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4801 - accuracy: 0.9170 - precision: 0.8521 - recall: 0.8083 - auc: 0.9583 - val_loss: 0.3514 - val_accuracy: 0.9399 - val_precision: 0.8940 - val_recall: 0.8618 - val_auc: 0.9767
# Epoch 71/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4792 - accuracy: 0.9124 - precision: 0.8431 - recall: 0.7979 - auc: 0.9588 - val_loss: 0.3482 - val_accuracy: 0.9392 - val_precision: 0.8927 - val_recall: 0.8600 - val_auc: 0.9772
# Epoch 72/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4859 - accuracy: 0.9132 - precision: 0.8445 - recall: 0.8003 - auc: 0.9576 - val_loss: 0.3513 - val_accuracy: 0.9402 - val_precision: 0.8936 - val_recall: 0.8636 - val_auc: 0.9767
# Epoch 73/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4796 - accuracy: 0.9168 - precision: 0.8518 - recall: 0.8077 - auc: 0.9584 - val_loss: 0.3469 - val_accuracy: 0.9445 - val_precision: 0.9037 - val_recall: 0.8706 - val_auc: 0.9767
# Epoch 74/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4629 - accuracy: 0.9164 - precision: 0.8496 - recall: 0.8087 - auc: 0.9614 - val_loss: 0.3331 - val_accuracy: 0.9434 - val_precision: 0.8989 - val_recall: 0.8718 - val_auc: 0.9783
# Epoch 75/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4827 - accuracy: 0.9138 - precision: 0.8458 - recall: 0.8015 - auc: 0.9578 - val_loss: 0.3544 - val_accuracy: 0.9399 - val_precision: 0.8906 - val_recall: 0.8659 - val_auc: 0.9761
# Epoch 76/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4897 - accuracy: 0.9139 - precision: 0.8445 - recall: 0.8035 - auc: 0.9566 - val_loss: 0.3350 - val_accuracy: 0.9437 - val_precision: 0.8995 - val_recall: 0.8724 - val_auc: 0.9791
# Epoch 77/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4786 - accuracy: 0.9152 - precision: 0.8487 - recall: 0.8040 - auc: 0.9586 - val_loss: 0.3548 - val_accuracy: 0.9411 - val_precision: 0.8955 - val_recall: 0.8653 - val_auc: 0.9763
# Epoch 78/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4662 - accuracy: 0.9160 - precision: 0.8491 - recall: 0.8075 - auc: 0.9605 - val_loss: 0.3467 - val_accuracy: 0.9412 - val_precision: 0.8922 - val_recall: 0.8701 - val_auc: 0.9770
# Epoch 79/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4691 - accuracy: 0.9188 - precision: 0.8547 - recall: 0.8136 - auc: 0.9600 - val_loss: 0.3418 - val_accuracy: 0.9421 - val_precision: 0.8959 - val_recall: 0.8695 - val_auc: 0.9775
# Epoch 80/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4487 - accuracy: 0.9219 - precision: 0.8587 - recall: 0.8229 - auc: 0.9630 - val_loss: 0.3287 - val_accuracy: 0.9433 - val_precision: 0.8969 - val_recall: 0.8736 - val_auc: 0.9788
# Epoch 81/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4589 - accuracy: 0.9192 - precision: 0.8542 - recall: 0.8164 - auc: 0.9612 - val_loss: 0.3313 - val_accuracy: 0.9434 - val_precision: 0.8989 - val_recall: 0.8718 - val_auc: 0.9792
# Epoch 82/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4699 - accuracy: 0.9156 - precision: 0.8469 - recall: 0.8084 - auc: 0.9600 - val_loss: 0.3341 - val_accuracy: 0.9439 - val_precision: 0.9005 - val_recall: 0.8718 - val_auc: 0.9788
# Epoch 83/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4732 - accuracy: 0.9136 - precision: 0.8455 - recall: 0.8006 - auc: 0.9601 - val_loss: 0.3296 - val_accuracy: 0.9445 - val_precision: 0.8998 - val_recall: 0.8754 - val_auc: 0.9792
# Epoch 84/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4618 - accuracy: 0.9201 - precision: 0.8574 - recall: 0.8159 - auc: 0.9612 - val_loss: 0.3392 - val_accuracy: 0.9460 - val_precision: 0.9038 - val_recall: 0.8771 - val_auc: 0.9777
# Epoch 85/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4629 - accuracy: 0.9166 - precision: 0.8498 - recall: 0.8096 - auc: 0.9612 - val_loss: 0.3355 - val_accuracy: 0.9409 - val_precision: 0.8930 - val_recall: 0.8677 - val_auc: 0.9782
# Epoch 86/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4646 - accuracy: 0.9169 - precision: 0.8500 - recall: 0.8108 - auc: 0.9610 - val_loss: 0.3302 - val_accuracy: 0.9409 - val_precision: 0.8921 - val_recall: 0.8689 - val_auc: 0.9791
# Epoch 87/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4771 - accuracy: 0.9162 - precision: 0.8470 - recall: 0.8115 - auc: 0.9590 - val_loss: 0.3372 - val_accuracy: 0.9437 - val_precision: 0.8981 - val_recall: 0.8742 - val_auc: 0.9778
# Epoch 88/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4625 - accuracy: 0.9187 - precision: 0.8544 - recall: 0.8133 - auc: 0.9613 - val_loss: 0.3524 - val_accuracy: 0.9372 - val_precision: 0.8866 - val_recall: 0.8588 - val_auc: 0.9764
# Epoch 89/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4581 - accuracy: 0.9185 - precision: 0.8523 - recall: 0.8152 - auc: 0.9616 - val_loss: 0.3340 - val_accuracy: 0.9446 - val_precision: 0.9013 - val_recall: 0.8742 - val_auc: 0.9788
# Epoch 90/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4620 - accuracy: 0.9185 - precision: 0.8521 - recall: 0.8158 - auc: 0.9609 - val_loss: 0.3365 - val_accuracy: 0.9417 - val_precision: 0.8919 - val_recall: 0.8724 - val_auc: 0.9785
# Epoch 91/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4698 - accuracy: 0.9158 - precision: 0.8474 - recall: 0.8087 - auc: 0.9601 - val_loss: 0.3271 - val_accuracy: 0.9436 - val_precision: 0.8975 - val_recall: 0.8742 - val_auc: 0.9795
# Epoch 92/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4614 - accuracy: 0.9188 - precision: 0.8544 - recall: 0.8142 - auc: 0.9614 - val_loss: 0.3342 - val_accuracy: 0.9436 - val_precision: 0.8966 - val_recall: 0.8754 - val_auc: 0.9788
# Epoch 93/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4577 - accuracy: 0.9197 - precision: 0.8558 - recall: 0.8165 - auc: 0.9618 - val_loss: 0.3350 - val_accuracy: 0.9412 - val_precision: 0.8927 - val_recall: 0.8695 - val_auc: 0.9781
# Epoch 94/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4651 - accuracy: 0.9176 - precision: 0.8526 - recall: 0.8106 - auc: 0.9606 - val_loss: 0.3477 - val_accuracy: 0.9392 - val_precision: 0.8898 - val_recall: 0.8636 - val_auc: 0.9771
# Epoch 95/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4500 - accuracy: 0.9204 - precision: 0.8551 - recall: 0.8206 - auc: 0.9627 - val_loss: 0.3450 - val_accuracy: 0.9400 - val_precision: 0.8931 - val_recall: 0.8636 - val_auc: 0.9772
# Epoch 96/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4582 - accuracy: 0.9180 - precision: 0.8520 - recall: 0.8134 - auc: 0.9619 - val_loss: 0.3441 - val_accuracy: 0.9424 - val_precision: 0.8994 - val_recall: 0.8665 - val_auc: 0.9777
# Epoch 97/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4418 - accuracy: 0.9234 - precision: 0.8618 - recall: 0.8260 - auc: 0.9644 - val_loss: 0.3278 - val_accuracy: 0.9445 - val_precision: 0.9008 - val_recall: 0.8742 - val_auc: 0.9789
# Epoch 98/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4634 - accuracy: 0.9191 - precision: 0.8520 - recall: 0.8184 - auc: 0.9608 - val_loss: 0.3354 - val_accuracy: 0.9423 - val_precision: 0.8960 - val_recall: 0.8701 - val_auc: 0.9784
# Epoch 99/500
# 848/848 [==============================] - 106s 126ms/step - loss: 0.4718 - accuracy: 0.9185 - precision: 0.8537 - recall: 0.8134 - auc: 0.9601 - val_loss: 0.3282 - val_accuracy: 0.9437 - val_precision: 0.8957 - val_recall: 0.8771 - val_auc: 0.9792
# Epoch 100/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4657 - accuracy: 0.9187 - precision: 0.8534 - recall: 0.8147 - auc: 0.9606 - val_loss: 0.3287 - val_accuracy: 0.9449 - val_precision: 0.9019 - val_recall: 0.8748 - val_auc: 0.9792
# Epoch 101/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4541 - accuracy: 0.9212 - precision: 0.8591 - recall: 0.8192 - auc: 0.9620 - val_loss: 0.3289 - val_accuracy: 0.9465 - val_precision: 0.9051 - val_recall: 0.8783 - val_auc: 0.9797
# Epoch 102/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4656 - accuracy: 0.9169 - precision: 0.8496 - recall: 0.8109 - auc: 0.9606 - val_loss: 0.3390 - val_accuracy: 0.9398 - val_precision: 0.8906 - val_recall: 0.8653 - val_auc: 0.9779
# Epoch 103/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4708 - accuracy: 0.9164 - precision: 0.8473 - recall: 0.8118 - auc: 0.9600 - val_loss: 0.3332 - val_accuracy: 0.9462 - val_precision: 0.9044 - val_recall: 0.8777 - val_auc: 0.9800
# Epoch 104/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4670 - accuracy: 0.9173 - precision: 0.8520 - recall: 0.8097 - auc: 0.9604 - val_loss: 0.3279 - val_accuracy: 0.9437 - val_precision: 0.8976 - val_recall: 0.8748 - val_auc: 0.9794
# Epoch 105/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4550 - accuracy: 0.9192 - precision: 0.8554 - recall: 0.8143 - auc: 0.9622 - val_loss: 0.3255 - val_accuracy: 0.9473 - val_precision: 0.9034 - val_recall: 0.8836 - val_auc: 0.9796
# Epoch 106/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4618 - accuracy: 0.9180 - precision: 0.8525 - recall: 0.8125 - auc: 0.9615 - val_loss: 0.3353 - val_accuracy: 0.9429 - val_precision: 0.8987 - val_recall: 0.8695 - val_auc: 0.9787
# Epoch 107/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4445 - accuracy: 0.9204 - precision: 0.8563 - recall: 0.8192 - auc: 0.9638 - val_loss: 0.3240 - val_accuracy: 0.9485 - val_precision: 0.9058 - val_recall: 0.8860 - val_auc: 0.9796
# Epoch 108/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4599 - accuracy: 0.9189 - precision: 0.8537 - recall: 0.8153 - auc: 0.9616 - val_loss: 0.3422 - val_accuracy: 0.9402 - val_precision: 0.8908 - val_recall: 0.8671 - val_auc: 0.9775
# Epoch 109/500
# 848/848 [==============================] - 106s 124ms/step - loss: 0.4658 - accuracy: 0.9192 - precision: 0.8539 - recall: 0.8165 - auc: 0.9605 - val_loss: 0.3317 - val_accuracy: 0.9443 - val_precision: 0.9002 - val_recall: 0.8742 - val_auc: 0.9793
# Epoch 110/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4574 - accuracy: 0.9179 - precision: 0.8514 - recall: 0.8137 - auc: 0.9619 - val_loss: 0.3336 - val_accuracy: 0.9431 - val_precision: 0.8964 - val_recall: 0.8736 - val_auc: 0.9787
# Epoch 111/500
# 848/848 [==============================] - 106s 124ms/step - loss: 0.4627 - accuracy: 0.9178 - precision: 0.8510 - recall: 0.8139 - auc: 0.9615 - val_loss: 0.3259 - val_accuracy: 0.9471 - val_precision: 0.9048 - val_recall: 0.8813 - val_auc: 0.9800
# Epoch 112/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4698 - accuracy: 0.9208 - precision: 0.8558 - recall: 0.8214 - auc: 0.9598 - val_loss: 0.3224 - val_accuracy: 0.9480 - val_precision: 0.9046 - val_recall: 0.8854 - val_auc: 0.9799
# Epoch 113/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4635 - accuracy: 0.9177 - precision: 0.8504 - recall: 0.8139 - auc: 0.9608 - val_loss: 0.3342 - val_accuracy: 0.9434 - val_precision: 0.8960 - val_recall: 0.8754 - val_auc: 0.9783
# Epoch 114/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4623 - accuracy: 0.9164 - precision: 0.8478 - recall: 0.8111 - auc: 0.9615 - val_loss: 0.3312 - val_accuracy: 0.9436 - val_precision: 0.8956 - val_recall: 0.8766 - val_auc: 0.9789
# Epoch 115/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4816 - accuracy: 0.9133 - precision: 0.8427 - recall: 0.8034 - auc: 0.9580 - val_loss: 0.3480 - val_accuracy: 0.9377 - val_precision: 0.8840 - val_recall: 0.8641 - val_auc: 0.9772
# Epoch 116/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4618 - accuracy: 0.9211 - precision: 0.8579 - recall: 0.8201 - auc: 0.9612 - val_loss: 0.3312 - val_accuracy: 0.9440 - val_precision: 0.8977 - val_recall: 0.8760 - val_auc: 0.9790
# Epoch 117/500
# 848/848 [==============================] - 107s 127ms/step - loss: 0.4657 - accuracy: 0.9181 - precision: 0.8516 - recall: 0.8142 - auc: 0.9606 - val_loss: 0.3429 - val_accuracy: 0.9423 - val_precision: 0.8955 - val_recall: 0.8706 - val_auc: 0.9781
# Epoch 118/500
# 848/848 [==============================] - 106s 124ms/step - loss: 0.4509 - accuracy: 0.9209 - precision: 0.8581 - recall: 0.8189 - auc: 0.9626 - val_loss: 0.3366 - val_accuracy: 0.9448 - val_precision: 0.8980 - val_recall: 0.8789 - val_auc: 0.9782
# Epoch 119/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4579 - accuracy: 0.9180 - precision: 0.8502 - recall: 0.8156 - auc: 0.9617 - val_loss: 0.3440 - val_accuracy: 0.9443 - val_precision: 0.8998 - val_recall: 0.8748 - val_auc: 0.9777
# Epoch 120/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4550 - accuracy: 0.9175 - precision: 0.8494 - recall: 0.8145 - auc: 0.9622 - val_loss: 0.3432 - val_accuracy: 0.9414 - val_precision: 0.8908 - val_recall: 0.8724 - val_auc: 0.9779
# Epoch 121/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4721 - accuracy: 0.9168 - precision: 0.8500 - recall: 0.8100 - auc: 0.9592 - val_loss: 0.3306 - val_accuracy: 0.9485 - val_precision: 0.9068 - val_recall: 0.8848 - val_auc: 0.9790
# Epoch 122/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4591 - accuracy: 0.9184 - precision: 0.8526 - recall: 0.8145 - auc: 0.9615 - val_loss: 0.3807 - val_accuracy: 0.9418 - val_precision: 0.9057 - val_recall: 0.8565 - val_auc: 0.9754
# Epoch 123/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4767 - accuracy: 0.9181 - precision: 0.8517 - recall: 0.8140 - auc: 0.9589 - val_loss: 0.3177 - val_accuracy: 0.9476 - val_precision: 0.9030 - val_recall: 0.8854 - val_auc: 0.9801
# Epoch 124/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4717 - accuracy: 0.9167 - precision: 0.8479 - recall: 0.8124 - auc: 0.9599 - val_loss: 0.3406 - val_accuracy: 0.9406 - val_precision: 0.8882 - val_recall: 0.8724 - val_auc: 0.9778
# Epoch 125/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4529 - accuracy: 0.9195 - precision: 0.8532 - recall: 0.8189 - auc: 0.9623 - val_loss: 0.3162 - val_accuracy: 0.9486 - val_precision: 0.9063 - val_recall: 0.8860 - val_auc: 0.9806
# Epoch 126/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4682 - accuracy: 0.9178 - precision: 0.8494 - recall: 0.8158 - auc: 0.9604 - val_loss: 0.3196 - val_accuracy: 0.9455 - val_precision: 0.9012 - val_recall: 0.8783 - val_auc: 0.9803
# Epoch 127/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4619 - accuracy: 0.9194 - precision: 0.8534 - recall: 0.8183 - auc: 0.9612 - val_loss: 0.3178 - val_accuracy: 0.9489 - val_precision: 0.9040 - val_recall: 0.8901 - val_auc: 0.9804
# Epoch 128/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4568 - accuracy: 0.9191 - precision: 0.8530 - recall: 0.8171 - auc: 0.9626 - val_loss: 0.3216 - val_accuracy: 0.9471 - val_precision: 0.9033 - val_recall: 0.8830 - val_auc: 0.9804
# Epoch 129/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.4773 - accuracy: 0.9163 - precision: 0.8496 - recall: 0.8084 - auc: 0.9589 - val_loss: 0.3328 - val_accuracy: 0.9431 - val_precision: 0.8983 - val_recall: 0.8712 - val_auc: 0.9792
# Epoch 130/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4469 - accuracy: 0.9228 - precision: 0.8598 - recall: 0.8258 - auc: 0.9633 - val_loss: 0.3337 - val_accuracy: 0.9451 - val_precision: 0.9001 - val_recall: 0.8777 - val_auc: 0.9783
# Epoch 131/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4513 - accuracy: 0.9218 - precision: 0.8578 - recall: 0.8236 - auc: 0.9627 - val_loss: 0.3304 - val_accuracy: 0.9433 - val_precision: 0.8959 - val_recall: 0.8748 - val_auc: 0.9789
# Epoch 132/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4524 - accuracy: 0.9215 - precision: 0.8578 - recall: 0.8224 - auc: 0.9623 - val_loss: 0.3319 - val_accuracy: 0.9426 - val_precision: 0.8956 - val_recall: 0.8718 - val_auc: 0.9787
# Epoch 133/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.4765 - accuracy: 0.9185 - precision: 0.8525 - recall: 0.8149 - auc: 0.9592 - val_loss: 0.3318 - val_accuracy: 0.9433 - val_precision: 0.8969 - val_recall: 0.8736 - val_auc: 0.9787
# Epoch 134/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4547 - accuracy: 0.9195 - precision: 0.8532 - recall: 0.8189 - auc: 0.9625 - val_loss: 0.3211 - val_accuracy: 0.9470 - val_precision: 0.9013 - val_recall: 0.8848 - val_auc: 0.9799
# Epoch 135/500
# 848/848 [==============================] - 106s 124ms/step - loss: 0.4683 - accuracy: 0.9183 - precision: 0.8533 - recall: 0.8131 - auc: 0.9601 - val_loss: 0.3308 - val_accuracy: 0.9442 - val_precision: 0.8992 - val_recall: 0.8748 - val_auc: 0.9791
# Epoch 136/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4700 - accuracy: 0.9176 - precision: 0.8513 - recall: 0.8121 - auc: 0.9597 - val_loss: 0.3262 - val_accuracy: 0.9467 - val_precision: 0.9012 - val_recall: 0.8836 - val_auc: 0.9794
# Epoch 137/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.4617 - accuracy: 0.9192 - precision: 0.8529 - recall: 0.8178 - auc: 0.9612 - val_loss: 0.3310 - val_accuracy: 0.9430 - val_precision: 0.8968 - val_recall: 0.8724 - val_auc: 0.9788
# Epoch 138/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4523 - accuracy: 0.9226 - precision: 0.8607 - recall: 0.8237 - auc: 0.9627 - val_loss: 0.3345 - val_accuracy: 0.9448 - val_precision: 0.8999 - val_recall: 0.8766 - val_auc: 0.9777
# Epoch 139/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4584 - accuracy: 0.9192 - precision: 0.8531 - recall: 0.8178 - auc: 0.9615 - val_loss: 0.3271 - val_accuracy: 0.9483 - val_precision: 0.9082 - val_recall: 0.8825 - val_auc: 0.9797
# Epoch 140/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4504 - accuracy: 0.9197 - precision: 0.8550 - recall: 0.8176 - auc: 0.9626 - val_loss: 0.3645 - val_accuracy: 0.9365 - val_precision: 0.8816 - val_recall: 0.8618 - val_auc: 0.9749
# Epoch 141/500
# 848/848 [==============================] - 108s 127ms/step - loss: 0.4531 - accuracy: 0.9199 - precision: 0.8559 - recall: 0.8174 - auc: 0.9622 - val_loss: 0.3268 - val_accuracy: 0.9442 - val_precision: 0.8978 - val_recall: 0.8766 - val_auc: 0.9788
# Epoch 142/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.4511 - accuracy: 0.9206 - precision: 0.8577 - recall: 0.8181 - auc: 0.9627 - val_loss: 0.3280 - val_accuracy: 0.9445 - val_precision: 0.8979 - val_recall: 0.8777 - val_auc: 0.9789
# Epoch 143/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4572 - accuracy: 0.9186 - precision: 0.8515 - recall: 0.8168 - auc: 0.9617 - val_loss: 0.3279 - val_accuracy: 0.9470 - val_precision: 0.9062 - val_recall: 0.8789 - val_auc: 0.9789
# Epoch 144/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4603 - accuracy: 0.9201 - precision: 0.8554 - recall: 0.8190 - auc: 0.9615 - val_loss: 0.3349 - val_accuracy: 0.9465 - val_precision: 0.9021 - val_recall: 0.8819 - val_auc: 0.9780
# Epoch 145/500
# 848/848 [==============================] - 107s 127ms/step - loss: 0.4550 - accuracy: 0.9208 - precision: 0.8583 - recall: 0.8184 - auc: 0.9620 - val_loss: 0.3264 - val_accuracy: 0.9451 - val_precision: 0.8991 - val_recall: 0.8789 - val_auc: 0.9794

# %% [markdown]
# #### Gráfica

# %%
accuracy_phase1 = history_phase1.history['accuracy']
val_accuracy_phase1 = history_phase1.history['val_accuracy']
loss_phase1 = history_phase1.history['loss']
val_loss_phase1 = history_phase1.history['val_loss']

plt.figure(figsize=(11, 5))
plt.suptitle("Fase 1: Entrenamiento de la parte de clasificación", fontsize=16, y=0.93)

plt.subplot(1, 2, 1)
plt.plot(accuracy_phase1, label='Accuracy')
plt.plot(val_accuracy_phase1, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss_phase1, label='Loss')
plt.plot(val_loss_phase1, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Ajustar el diseño para que no se superponga con el título
plt.show()

# %% [markdown]
# ### Fase 2: Fine-Tuning (descongelar algunas capas del backbone)

# %%
# Ruta del modelo guardado
model_path = f'./modelos/Lead III/modelo_phase1_{seed_value}.keras'

# Cargar el modelo
model = load_model_safely(model_path)
# Out:
# Modelo cargado desde ./modelos/Lead III/modelo_phase1_3367708436.keras

# %%
# Descongelar las últimas 30 capas del modelo base (%10 de las capas)
# Se descongelan las últimas capas para que el modelo pueda aprender características específicas de los
# datos de entrenamiento, mientras que las capas anteriores siguen congeladas para mantener las
# características generales aprendidas durante el preentrenamiento.
# Esto es útil para evitar el sobreajuste y mejorar la generalización del modelo.
for layer in base_model.layers[-30:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=LEARNING_RATE, beta_1=BETA_1, beta_2=BETA_2),
              loss='categorical_crossentropy',
              metrics=METRICS)

early_stopping_phase2 = EarlyStopping(monitor='val_loss',
                                      patience=PATIENCE_FASE2,
                                      restore_best_weights=True
                                      )

# Entrenamiento con Fine-Tuning
history_phase2 = model.fit(train_generator,
                           validation_data=validation_generator,
                           epochs=EPOCH,
                           callbacks=[early_stopping_phase2]
                           )

# Guardar el modelo incluyendo el valor de seed_value en el nombre del archivo
model.save(f'./modelos/Lead III/modelo_phase2_{seed_value}.keras')
# Out:
# Epoch 1/500
# 848/848 [==============================] - 112s 128ms/step - loss: 0.5627 - accuracy: 0.9079 - precision: 0.8297 - recall: 0.7945 - auc: 0.9529 - val_loss: 0.4768 - val_accuracy: 0.9120 - val_precision: 0.8310 - val_recall: 0.8133 - val_auc: 0.9607
# Epoch 2/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.4999 - accuracy: 0.9124 - precision: 0.8418 - recall: 0.7999 - auc: 0.9549 - val_loss: 0.4468 - val_accuracy: 0.9240 - val_precision: 0.8645 - val_recall: 0.8252 - val_auc: 0.9642
# Epoch 3/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.4844 - accuracy: 0.9161 - precision: 0.8468 - recall: 0.8111 - auc: 0.9575 - val_loss: 0.4394 - val_accuracy: 0.9192 - val_precision: 0.8473 - val_recall: 0.8258 - val_auc: 0.9653
# Epoch 4/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.4496 - accuracy: 0.9222 - precision: 0.8571 - recall: 0.8268 - auc: 0.9628 - val_loss: 0.3203 - val_accuracy: 0.9468 - val_precision: 0.9022 - val_recall: 0.8830 - val_auc: 0.9806
# Epoch 5/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.4411 - accuracy: 0.9211 - precision: 0.8548 - recall: 0.8243 - auc: 0.9644 - val_loss: 0.3180 - val_accuracy: 0.9443 - val_precision: 0.8954 - val_recall: 0.8801 - val_auc: 0.9803
# Epoch 6/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.4333 - accuracy: 0.9240 - precision: 0.8606 - recall: 0.8305 - auc: 0.9652 - val_loss: 0.3150 - val_accuracy: 0.9458 - val_precision: 0.9018 - val_recall: 0.8789 - val_auc: 0.9811
# Epoch 7/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.4300 - accuracy: 0.9246 - precision: 0.8607 - recall: 0.8332 - auc: 0.9662 - val_loss: 0.3302 - val_accuracy: 0.9380 - val_precision: 0.8832 - val_recall: 0.8665 - val_auc: 0.9793
# Epoch 8/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.4243 - accuracy: 0.9275 - precision: 0.8668 - recall: 0.8388 - auc: 0.9664 - val_loss: 0.3814 - val_accuracy: 0.9353 - val_precision: 0.8792 - val_recall: 0.8594 - val_auc: 0.9730
# Epoch 9/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.4039 - accuracy: 0.9298 - precision: 0.8730 - recall: 0.8417 - auc: 0.9693 - val_loss: 0.2996 - val_accuracy: 0.9499 - val_precision: 0.9064 - val_recall: 0.8919 - val_auc: 0.9817
# Epoch 10/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.4131 - accuracy: 0.9303 - precision: 0.8725 - recall: 0.8445 - auc: 0.9677 - val_loss: 0.3054 - val_accuracy: 0.9454 - val_precision: 0.8963 - val_recall: 0.8836 - val_auc: 0.9818
# Epoch 11/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.4010 - accuracy: 0.9320 - precision: 0.8749 - recall: 0.8493 - auc: 0.9696 - val_loss: 0.3061 - val_accuracy: 0.9477 - val_precision: 0.9007 - val_recall: 0.8890 - val_auc: 0.9809
# Epoch 12/500
# 848/848 [==============================] - 133s 157ms/step - loss: 0.3820 - accuracy: 0.9345 - precision: 0.8786 - recall: 0.8563 - auc: 0.9721 - val_loss: 0.2756 - val_accuracy: 0.9508 - val_precision: 0.9072 - val_recall: 0.8949 - val_auc: 0.9849
# Epoch 13/500
# 848/848 [==============================] - 113s 134ms/step - loss: 0.3914 - accuracy: 0.9333 - precision: 0.8764 - recall: 0.8534 - auc: 0.9708 - val_loss: 0.3789 - val_accuracy: 0.9310 - val_precision: 0.8693 - val_recall: 0.8523 - val_auc: 0.9748
# Epoch 14/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3742 - accuracy: 0.9355 - precision: 0.8809 - recall: 0.8583 - auc: 0.9734 - val_loss: 0.2960 - val_accuracy: 0.9495 - val_precision: 0.9038 - val_recall: 0.8931 - val_auc: 0.9816
# Epoch 15/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.3705 - accuracy: 0.9339 - precision: 0.8766 - recall: 0.8560 - auc: 0.9744 - val_loss: 0.2891 - val_accuracy: 0.9499 - val_precision: 0.9059 - val_recall: 0.8925 - val_auc: 0.9833
# Epoch 16/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.3650 - accuracy: 0.9369 - precision: 0.8826 - recall: 0.8625 - auc: 0.9745 - val_loss: 0.3038 - val_accuracy: 0.9436 - val_precision: 0.8951 - val_recall: 0.8771 - val_auc: 0.9822
# Epoch 17/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.3568 - accuracy: 0.9390 - precision: 0.8881 - recall: 0.8649 - auc: 0.9756 - val_loss: 0.2780 - val_accuracy: 0.9526 - val_precision: 0.9118 - val_recall: 0.8972 - val_auc: 0.9839
# Epoch 18/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3495 - accuracy: 0.9411 - precision: 0.8912 - recall: 0.8706 - auc: 0.9765 - val_loss: 0.2729 - val_accuracy: 0.9556 - val_precision: 0.9153 - val_recall: 0.9061 - val_auc: 0.9845
# Epoch 19/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.3478 - accuracy: 0.9407 - precision: 0.8894 - recall: 0.8709 - auc: 0.9765 - val_loss: 0.2986 - val_accuracy: 0.9483 - val_precision: 0.9014 - val_recall: 0.8907 - val_auc: 0.9824
# Epoch 20/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3492 - accuracy: 0.9395 - precision: 0.8872 - recall: 0.8686 - auc: 0.9760 - val_loss: 0.3158 - val_accuracy: 0.9423 - val_precision: 0.8903 - val_recall: 0.8771 - val_auc: 0.9805
# Epoch 21/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.3326 - accuracy: 0.9435 - precision: 0.8941 - recall: 0.8780 - auc: 0.9786 - val_loss: 0.2651 - val_accuracy: 0.9532 - val_precision: 0.9095 - val_recall: 0.9025 - val_auc: 0.9857
# Epoch 22/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3410 - accuracy: 0.9427 - precision: 0.8926 - recall: 0.8764 - auc: 0.9769 - val_loss: 0.2921 - val_accuracy: 0.9482 - val_precision: 0.9028 - val_recall: 0.8884 - val_auc: 0.9838
# Epoch 23/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.3275 - accuracy: 0.9446 - precision: 0.8967 - recall: 0.8798 - auc: 0.9788 - val_loss: 0.2965 - val_accuracy: 0.9483 - val_precision: 0.9019 - val_recall: 0.8901 - val_auc: 0.9827
# Epoch 24/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3295 - accuracy: 0.9435 - precision: 0.8944 - recall: 0.8779 - auc: 0.9791 - val_loss: 0.2707 - val_accuracy: 0.9547 - val_precision: 0.9140 - val_recall: 0.9037 - val_auc: 0.9844
# Epoch 25/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.3252 - accuracy: 0.9461 - precision: 0.8990 - recall: 0.8835 - auc: 0.9789 - val_loss: 0.2680 - val_accuracy: 0.9523 - val_precision: 0.9077 - val_recall: 0.9008 - val_auc: 0.9852
# Epoch 26/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3083 - accuracy: 0.9467 - precision: 0.9012 - recall: 0.8836 - auc: 0.9813 - val_loss: 0.3057 - val_accuracy: 0.9446 - val_precision: 0.8937 - val_recall: 0.8836 - val_auc: 0.9825
# Epoch 27/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3045 - accuracy: 0.9496 - precision: 0.9057 - recall: 0.8910 - auc: 0.9814 - val_loss: 0.2838 - val_accuracy: 0.9525 - val_precision: 0.9102 - val_recall: 0.8984 - val_auc: 0.9841
# Epoch 28/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.3077 - accuracy: 0.9470 - precision: 0.8997 - recall: 0.8867 - auc: 0.9814 - val_loss: 0.2840 - val_accuracy: 0.9510 - val_precision: 0.9058 - val_recall: 0.8972 - val_auc: 0.9839
# Epoch 29/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.3128 - accuracy: 0.9463 - precision: 0.9004 - recall: 0.8829 - auc: 0.9811 - val_loss: 0.3079 - val_accuracy: 0.9429 - val_precision: 0.8901 - val_recall: 0.8801 - val_auc: 0.9829
# Epoch 30/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2917 - accuracy: 0.9497 - precision: 0.9051 - recall: 0.8923 - auc: 0.9830 - val_loss: 0.2783 - val_accuracy: 0.9529 - val_precision: 0.9104 - val_recall: 0.9002 - val_auc: 0.9830
# Epoch 31/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2968 - accuracy: 0.9498 - precision: 0.9052 - recall: 0.8928 - auc: 0.9825 - val_loss: 0.2830 - val_accuracy: 0.9551 - val_precision: 0.9141 - val_recall: 0.9055 - val_auc: 0.9831
# Epoch 32/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.3037 - accuracy: 0.9481 - precision: 0.9020 - recall: 0.8891 - auc: 0.9814 - val_loss: 0.2717 - val_accuracy: 0.9545 - val_precision: 0.9124 - val_recall: 0.9049 - val_auc: 0.9852
# Epoch 33/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.2950 - accuracy: 0.9516 - precision: 0.9100 - recall: 0.8950 - auc: 0.9825 - val_loss: 0.2725 - val_accuracy: 0.9544 - val_precision: 0.9109 - val_recall: 0.9061 - val_auc: 0.9846
# Epoch 34/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.3005 - accuracy: 0.9497 - precision: 0.9056 - recall: 0.8917 - auc: 0.9818 - val_loss: 0.2759 - val_accuracy: 0.9564 - val_precision: 0.9151 - val_recall: 0.9102 - val_auc: 0.9841
# Epoch 35/500
# 848/848 [==============================] - 105s 123ms/step - loss: 0.2833 - accuracy: 0.9513 - precision: 0.9087 - recall: 0.8951 - auc: 0.9839 - val_loss: 0.2756 - val_accuracy: 0.9548 - val_precision: 0.9126 - val_recall: 0.9061 - val_auc: 0.9852
# Epoch 36/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2876 - accuracy: 0.9507 - precision: 0.9066 - recall: 0.8950 - auc: 0.9832 - val_loss: 0.2701 - val_accuracy: 0.9564 - val_precision: 0.9186 - val_recall: 0.9061 - val_auc: 0.9849
# Epoch 37/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.2877 - accuracy: 0.9517 - precision: 0.9087 - recall: 0.8971 - auc: 0.9834 - val_loss: 0.2555 - val_accuracy: 0.9581 - val_precision: 0.9191 - val_recall: 0.9126 - val_auc: 0.9855
# Epoch 38/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2830 - accuracy: 0.9527 - precision: 0.9129 - recall: 0.8962 - auc: 0.9836 - val_loss: 0.2656 - val_accuracy: 0.9561 - val_precision: 0.9140 - val_recall: 0.9102 - val_auc: 0.9846
# Epoch 39/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2644 - accuracy: 0.9555 - precision: 0.9161 - recall: 0.9050 - auc: 0.9857 - val_loss: 0.2987 - val_accuracy: 0.9483 - val_precision: 0.9004 - val_recall: 0.8919 - val_auc: 0.9822
# Epoch 40/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.2767 - accuracy: 0.9542 - precision: 0.9129 - recall: 0.9031 - auc: 0.9841 - val_loss: 0.2847 - val_accuracy: 0.9507 - val_precision: 0.9071 - val_recall: 0.8943 - val_auc: 0.9837
# Epoch 41/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2675 - accuracy: 0.9535 - precision: 0.9123 - recall: 0.9006 - auc: 0.9856 - val_loss: 0.2568 - val_accuracy: 0.9560 - val_precision: 0.9154 - val_recall: 0.9079 - val_auc: 0.9867
# Epoch 42/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.2653 - accuracy: 0.9559 - precision: 0.9181 - recall: 0.9041 - auc: 0.9851 - val_loss: 0.2621 - val_accuracy: 0.9545 - val_precision: 0.9115 - val_recall: 0.9061 - val_auc: 0.9861
# Epoch 43/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2562 - accuracy: 0.9568 - precision: 0.9189 - recall: 0.9072 - auc: 0.9866 - val_loss: 0.2788 - val_accuracy: 0.9554 - val_precision: 0.9133 - val_recall: 0.9079 - val_auc: 0.9838
# Epoch 44/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2509 - accuracy: 0.9571 - precision: 0.9192 - recall: 0.9081 - auc: 0.9866 - val_loss: 0.3182 - val_accuracy: 0.9421 - val_precision: 0.8870 - val_recall: 0.8807 - val_auc: 0.9813
# Epoch 45/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2656 - accuracy: 0.9550 - precision: 0.9152 - recall: 0.9038 - auc: 0.9851 - val_loss: 0.3105 - val_accuracy: 0.9434 - val_precision: 0.8894 - val_recall: 0.8836 - val_auc: 0.9825
# Epoch 46/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2475 - accuracy: 0.9569 - precision: 0.9177 - recall: 0.9090 - auc: 0.9874 - val_loss: 0.3309 - val_accuracy: 0.9403 - val_precision: 0.8834 - val_recall: 0.8771 - val_auc: 0.9798
# Epoch 47/500
# 848/848 [==============================] - 106s 124ms/step - loss: 0.2630 - accuracy: 0.9546 - precision: 0.9155 - recall: 0.9018 - auc: 0.9860 - val_loss: 0.2724 - val_accuracy: 0.9517 - val_precision: 0.9061 - val_recall: 0.9002 - val_auc: 0.9849
# Epoch 48/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2466 - accuracy: 0.9579 - precision: 0.9204 - recall: 0.9102 - auc: 0.9873 - val_loss: 0.2618 - val_accuracy: 0.9542 - val_precision: 0.9119 - val_recall: 0.9043 - val_auc: 0.9859
# Epoch 49/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.2541 - accuracy: 0.9566 - precision: 0.9187 - recall: 0.9066 - auc: 0.9866 - val_loss: 0.3115 - val_accuracy: 0.9460 - val_precision: 0.8952 - val_recall: 0.8878 - val_auc: 0.9815
# Epoch 50/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2555 - accuracy: 0.9561 - precision: 0.9172 - recall: 0.9063 - auc: 0.9866 - val_loss: 0.2747 - val_accuracy: 0.9513 - val_precision: 0.9045 - val_recall: 0.9002 - val_auc: 0.9848
# Epoch 51/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2515 - accuracy: 0.9574 - precision: 0.9193 - recall: 0.9094 - auc: 0.9868 - val_loss: 0.2856 - val_accuracy: 0.9513 - val_precision: 0.9049 - val_recall: 0.8996 - val_auc: 0.9837
# Epoch 52/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2522 - accuracy: 0.9569 - precision: 0.9188 - recall: 0.9078 - auc: 0.9872 - val_loss: 0.3263 - val_accuracy: 0.9427 - val_precision: 0.8886 - val_recall: 0.8813 - val_auc: 0.9797
# Epoch 53/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2488 - accuracy: 0.9576 - precision: 0.9200 - recall: 0.9094 - auc: 0.9869 - val_loss: 0.2836 - val_accuracy: 0.9498 - val_precision: 0.9024 - val_recall: 0.8960 - val_auc: 0.9836
# Epoch 54/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2502 - accuracy: 0.9570 - precision: 0.9172 - recall: 0.9100 - auc: 0.9866 - val_loss: 0.2715 - val_accuracy: 0.9553 - val_precision: 0.9132 - val_recall: 0.9073 - val_auc: 0.9840
# Epoch 55/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2492 - accuracy: 0.9567 - precision: 0.9185 - recall: 0.9075 - auc: 0.9871 - val_loss: 0.2601 - val_accuracy: 0.9585 - val_precision: 0.9207 - val_recall: 0.9126 - val_auc: 0.9859
# Epoch 56/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2361 - accuracy: 0.9601 - precision: 0.9252 - recall: 0.9143 - auc: 0.9884 - val_loss: 0.2819 - val_accuracy: 0.9505 - val_precision: 0.9042 - val_recall: 0.8972 - val_auc: 0.9846
# Epoch 57/500
# 848/848 [==============================] - 106s 125ms/step - loss: 0.2460 - accuracy: 0.9591 - precision: 0.9227 - recall: 0.9131 - auc: 0.9873 - val_loss: 0.2750 - val_accuracy: 0.9525 - val_precision: 0.9078 - val_recall: 0.9014 - val_auc: 0.9848
# Epoch 58/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2495 - accuracy: 0.9577 - precision: 0.9205 - recall: 0.9091 - auc: 0.9869 - val_loss: 0.2662 - val_accuracy: 0.9563 - val_precision: 0.9160 - val_recall: 0.9084 - val_auc: 0.9856
# Epoch 59/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2262 - accuracy: 0.9602 - precision: 0.9242 - recall: 0.9159 - auc: 0.9895 - val_loss: 0.2849 - val_accuracy: 0.9522 - val_precision: 0.9057 - val_recall: 0.9025 - val_auc: 0.9825
# Epoch 60/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2418 - accuracy: 0.9593 - precision: 0.9222 - recall: 0.9143 - auc: 0.9876 - val_loss: 0.2684 - val_accuracy: 0.9544 - val_precision: 0.9104 - val_recall: 0.9067 - val_auc: 0.9854
# Epoch 61/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2355 - accuracy: 0.9603 - precision: 0.9249 - recall: 0.9156 - auc: 0.9885 - val_loss: 0.2679 - val_accuracy: 0.9527 - val_precision: 0.9079 - val_recall: 0.9025 - val_auc: 0.9855
# Epoch 62/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2324 - accuracy: 0.9608 - precision: 0.9254 - recall: 0.9173 - auc: 0.9886 - val_loss: 0.2645 - val_accuracy: 0.9556 - val_precision: 0.9123 - val_recall: 0.9096 - val_auc: 0.9859
# Epoch 63/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2365 - accuracy: 0.9612 - precision: 0.9263 - recall: 0.9178 - auc: 0.9881 - val_loss: 0.3047 - val_accuracy: 0.9519 - val_precision: 0.9066 - val_recall: 0.9002 - val_auc: 0.9825
# Epoch 64/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.2304 - accuracy: 0.9591 - precision: 0.9230 - recall: 0.9125 - auc: 0.9889 - val_loss: 0.2611 - val_accuracy: 0.9585 - val_precision: 0.9202 - val_recall: 0.9132 - val_auc: 0.9860
# Epoch 65/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2265 - accuracy: 0.9622 - precision: 0.9288 - recall: 0.9193 - auc: 0.9893 - val_loss: 0.2811 - val_accuracy: 0.9520 - val_precision: 0.9067 - val_recall: 0.9008 - val_auc: 0.9842
# Epoch 66/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2359 - accuracy: 0.9591 - precision: 0.9227 - recall: 0.9131 - auc: 0.9885 - val_loss: 0.2986 - val_accuracy: 0.9501 - val_precision: 0.9016 - val_recall: 0.8984 - val_auc: 0.9835
# Epoch 67/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2197 - accuracy: 0.9640 - precision: 0.9324 - recall: 0.9230 - auc: 0.9895 - val_loss: 0.2941 - val_accuracy: 0.9539 - val_precision: 0.9108 - val_recall: 0.9043 - val_auc: 0.9831
# Epoch 68/500
# 848/848 [==============================] - 103s 122ms/step - loss: 0.2212 - accuracy: 0.9632 - precision: 0.9298 - recall: 0.9223 - auc: 0.9896 - val_loss: 0.3802 - val_accuracy: 0.9369 - val_precision: 0.8768 - val_recall: 0.8701 - val_auc: 0.9743
# Epoch 69/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.2260 - accuracy: 0.9621 - precision: 0.9281 - recall: 0.9198 - auc: 0.9890 - val_loss: 0.3042 - val_accuracy: 0.9496 - val_precision: 0.9009 - val_recall: 0.8972 - val_auc: 0.9820
# Epoch 70/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.2220 - accuracy: 0.9615 - precision: 0.9272 - recall: 0.9181 - auc: 0.9894 - val_loss: 0.2814 - val_accuracy: 0.9520 - val_precision: 0.9076 - val_recall: 0.8996 - val_auc: 0.9842
# Epoch 71/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2225 - accuracy: 0.9647 - precision: 0.9326 - recall: 0.9260 - auc: 0.9888 - val_loss: 0.2791 - val_accuracy: 0.9566 - val_precision: 0.9171 - val_recall: 0.9084 - val_auc: 0.9848
# Epoch 72/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.2256 - accuracy: 0.9614 - precision: 0.9264 - recall: 0.9187 - auc: 0.9892 - val_loss: 0.2920 - val_accuracy: 0.9536 - val_precision: 0.9102 - val_recall: 0.9037 - val_auc: 0.9827
# Epoch 73/500
# 848/848 [==============================] - 105s 124ms/step - loss: 0.2227 - accuracy: 0.9610 - precision: 0.9260 - recall: 0.9173 - auc: 0.9894 - val_loss: 0.3187 - val_accuracy: 0.9449 - val_precision: 0.8938 - val_recall: 0.8848 - val_auc: 0.9801
# Epoch 74/500
# 848/848 [==============================] - 104s 123ms/step - loss: 0.2112 - accuracy: 0.9649 - precision: 0.9336 - recall: 0.9255 - auc: 0.9905 - val_loss: 0.2826 - val_accuracy: 0.9553 - val_precision: 0.9122 - val_recall: 0.9084 - val_auc: 0.9838
# Epoch 75/500
# 848/848 [==============================] - 107s 126ms/step - loss: 0.2095 - accuracy: 0.9630 - precision: 0.9300 - recall: 0.9212 - auc: 0.9905 - val_loss: 0.3021 - val_accuracy: 0.9474 - val_precision: 0.8972 - val_recall: 0.8919 - val_auc: 0.9824
# Epoch 76/500
# 848/848 [==============================] - 103s 121ms/step - loss: 0.2109 - accuracy: 0.9640 - precision: 0.9325 - recall: 0.9230 - auc: 0.9904 - val_loss: 0.3232 - val_accuracy: 0.9452 - val_precision: 0.8925 - val_recall: 0.8878 - val_auc: 0.9807
# Epoch 77/500
# 848/848 [==============================] - 104s 122ms/step - loss: 0.2046 - accuracy: 0.9661 - precision: 0.9354 - recall: 0.9286 - auc: 0.9908 - val_loss: 0.3064 - val_accuracy: 0.9474 - val_precision: 0.8967 - val_recall: 0.8925 - val_auc: 0.9831

# %% [markdown]
# #### Gráfica

# %%
accuracy_phase2 = history_phase2.history['accuracy']
val_accuracy_phase2 = history_phase2.history['val_accuracy']
loss_phase2 = history_phase2.history['loss']
val_loss_phase2 = history_phase2.history['val_loss']

plt.figure(figsize=(11, 5))
plt.suptitle("Fase 2: Entrenamiento con Fine-Tuning", fontsize=16, y=0.93)

plt.subplot(1, 2, 1)
plt.plot(accuracy_phase2, label='Accuracy')
plt.plot(val_accuracy_phase2, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(loss_phase2, label='Loss')
plt.plot(val_loss_phase2, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss')

plt.tight_layout(rect=[0, 0, 1, 0.95])  # Ajustar el diseño para que no se superponga con el título
plt.show()

# %%
# Ruta del modelo guardado
model_path = f'./modelos/Lead III/modelo_phase2_{seed_value}.keras'

# Cargar el modelo
model = load_model_safely(model_path)
# Out:
# Modelo cargado desde ./modelos/Lead III/modelo_phase2_3367708436.keras

# %% [markdown]
# ### Mostrar resultados finales de entrenamiento-validación

# %% [markdown]
# #### Primer modelo

# %%
# Evaluar sobre entrenamiento
train_loss, train_accuracy, train_precision, train_recall, train_auc = model.evaluate(train_generator)
print("\n📊 Resultados en el conjunto de ENTRENAMIENTO:")
print(f"Train Loss: {train_loss:.4f}")
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Train Precision: {train_precision:.4f}")
print(f"Train Recall: {train_recall:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Train F1-Score: {f1_score(train_recall, train_precision):.4f}\n")

# Evaluar sobre validación
val_loss, val_accuracy, val_precision, val_recall, val_auc = model.evaluate(validation_generator)
print("\n📊 Resultados en el conjunto de VALIDACIÓN:")
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
print(f"Val AUC: {val_auc:.4f}")
print(f"Val F1-Score: {f1_score(val_recall, val_precision):.4f}")

# Crear un DataFrame con los resultados
resultados = pd.DataFrame({
    '': ['Entrenamiento', 'Validación'],
    'Loss': [train_loss, val_loss],
    'Accuracy': [train_accuracy, val_accuracy],
    'Precisión': [train_precision, val_precision],
    'Sensibilidad': [train_recall, val_recall],
    'AUC': [train_auc, val_auc],
    'F1-Score': [f1_score(train_recall, train_precision), f1_score(val_recall, val_precision)]
})

# Guardar el DataFrame en un archivo Excel
ruta_excel = './modelos/Lead III/resultados_entrenamiento_validacion_fase1.xlsx'
resultados.to_excel(ruta_excel, index=False)

print(f"📁 Resultados guardados en: {ruta_excel}")
# Out:
# 848/848 [==============================] - 141s 158ms/step - loss: 0.3370 - accuracy: 0.9414 - precision: 0.8913 - recall: 0.8721 - auc: 0.9782
#
# 📊 Resultados en el conjunto de ENTRENAMIENTO:
# Train Loss: 0.3370
# Train Accuracy: 0.9414
# Train Precision: 0.8913
# Train Recall: 0.8721
# Train AUC: 0.9782
# Train F1-Score: 0.8816
#
# 14/14 [==============================] - 13s 780ms/step - loss: 0.3162 - accuracy: 0.9485 - precision: 0.9063 - recall: 0.8854 - auc: 0.9806
#
# 📊 Resultados en el conjunto de VALIDACIÓN:
# Val Loss: 0.3162
# Val Accuracy: 0.9485
# Val Precision: 0.9063
# Val Recall: 0.8854
# Val AUC: 0.9806
# Val F1-Score: 0.8957
# 📁 Resultados guardados en: ./modelos/Lead III/resultados_entrenamiento_validacion_fase1.xlsx

# %% [markdown]
# #### Segundo modelo

# %%
# Evaluar sobre entrenamiento
train_loss, train_accuracy, train_precision, train_recall, train_auc = model.evaluate(train_generator)
print("\n📊 Resultados en el conjunto de ENTRENAMIENTO:")
print(f"Train Loss: {train_loss:.4f}")
print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Train Precision: {train_precision:.4f}")
print(f"Train Recall: {train_recall:.4f}")
print(f"Train AUC: {train_auc:.4f}")
print(f"Train F1-Score: {f1_score(train_recall, train_precision):.4f}\n")

# Evaluar sobre validación
val_loss, val_accuracy, val_precision, val_recall, val_auc = model.evaluate(validation_generator)
print("\n📊 Resultados en el conjunto de VALIDACIÓN:")
print(f"Val Loss: {val_loss:.4f}")
print(f"Val Accuracy: {val_accuracy:.4f}")
print(f"Val Precision: {val_precision:.4f}")
print(f"Val Recall: {val_recall:.4f}")
print(f"Val AUC: {val_auc:.4f}")
print(f"Val F1-Score: {f1_score(val_recall, val_precision):.4f}")

# Crear un DataFrame con los resultados
resultados = pd.DataFrame({
    '': ['Entrenamiento', 'Validación'],
    'Loss': [train_loss, val_loss],
    'Accuracy': [train_accuracy, val_accuracy],
    'Precisión': [train_precision, val_precision],
    'Sensibilidad': [train_recall, val_recall],
    'AUC': [train_auc, val_auc],
    'F1-Score': [f1_score(train_recall, train_precision), f1_score(val_recall, val_precision)]
})

# Guardar el DataFrame en un archivo Excel
ruta_excel = './modelos/Lead III/resultados_entrenamiento_validacion_fase2.xlsx'
resultados.to_excel(ruta_excel, index=False)

print(f"📁 Resultados guardados en: {ruta_excel}")
# Out:
# 848/848 [==============================] - 100s 117ms/step - loss: 0.1885 - accuracy: 0.9674 - precision: 0.9376 - recall: 0.9314 - auc: 0.9931
#
# 📊 Resultados en el conjunto de ENTRENAMIENTO:
# Train Loss: 0.1885
# Train Accuracy: 0.9674
# Train Precision: 0.9376
# Train Recall: 0.9314
# Train AUC: 0.9931
# Train F1-Score: 0.9345
#
# 14/14 [==============================] - 4s 283ms/step - loss: 0.2555 - accuracy: 0.9581 - precision: 0.9191 - recall: 0.9126 - auc: 0.9855
#
# 📊 Resultados en el conjunto de VALIDACIÓN:
# Val Loss: 0.2555
# Val Accuracy: 0.9581
# Val Precision: 0.9191
# Val Recall: 0.9126
# Val AUC: 0.9855
# Val F1-Score: 0.9158
# 📁 Resultados guardados en: ./modelos/Lead III/resultados_entrenamiento_validacion_fase2.xlsx

# %% [markdown]
# # Predicción

# %% [markdown]
# ## Evaluar el modelo en el conjunto de prueba

# %% [markdown]
# ### Primer modelo

# %%
if model is not None:
    test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_generator)
    print(f"Test Loss: {test_loss}")
    print(f"Test Accuracy: {test_accuracy}")
    print(f"Test Precision: {test_precision}")
    print(f"Test Recall: {test_recall}")
    print(f"Test AUC: {test_auc}")
    print(f"Test F1-Score: {f1_score(test_recall, test_precision)}")
else:
    print("No se pudo cargar el modelo para la evaluación.")
# Out:
# 17/17 [==============================] - 15s 919ms/step - loss: 0.3615 - accuracy: 0.9366 - precision: 0.8838 - recall: 0.8596 - auc: 0.9759
# Test Loss: 0.3614816963672638
# Test Accuracy: 0.9366430044174194
# Test Precision: 0.883811354637146
# Test Recall: 0.8595744967460632
# Test AUC: 0.9758841395378113
# Test F1-Score: 0.8715244031626282

# %% [markdown]
# ### Segundo modelo

# %%
if model is not None:
    test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(test_generator)
    print(f"Test Loss: {test_loss}")
    print(f"Test Accuracy: {test_accuracy}")
    print(f"Test Precision: {test_precision}")
    print(f"Test Recall: {test_recall}")
    print(f"Test AUC: {test_auc}")
    print(f"Test F1-Score: {f1_score(test_recall, test_precision)}")
else:
    print("No se pudo cargar el modelo para la evaluación.")
# Out:
# 17/17 [==============================] - 16s 940ms/step - loss: 0.3163 - accuracy: 0.9470 - precision: 0.8994 - recall: 0.8875 - auc: 0.9809
# Test Loss: 0.3162640929222107
# Test Accuracy: 0.9470449090003967
# Test Precision: 0.8993771076202393
# Test Recall: 0.8874704241752625
# Test AUC: 0.9808946251869202
# Test F1-Score: 0.893384045724389

# %% [markdown]
# ## Curva ROC

# %%
# Predicciones en el conjunto de prueba
predictions = model.predict(test_generator)
#predicted_classes = np.argmax(predictions, axis=1)  # Obtener las clases predichas
true_classes = test_generator.classes  # Obtener las clases verdaderas
true_classes_one_hot = to_categorical(true_classes, num_classes=NUM_CLASES)    # Convertir true_classes
                                                                                # a One-Hot Encoding
class_labels = list(test_generator.class_indices.keys())  # Obtener las etiquetas de clase

# Graficar la curva ROC para cada clase (problema multiclase)
# Enfoque One-vs-Rest: calcular la curva ROC para cada clase contra el resto
# Para cada clase, se considera esa clase como positiva y todas las demás como negativas.
# Esto permite evaluar el rendimiento del modelo en cada clase individualmente.
# Cada curva ROC muestra cómo de bien el modelo distingue esa clase concreta del resto.
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(NUM_CLASES):
    fpr[i], tpr[i], _ = roc_curve(true_classes_one_hot[:, i], predictions[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Dibujar todas las curvas ROC en una sola figura
plt.figure(figsize=(10, 6))
for i in range(NUM_CLASES):
    plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.3f})')

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Tasa de falsos positivos')
plt.ylabel('Tasa de verdaderos positivos')
plt.title('Curvas ROC para cada clase')
plt.legend(loc='lower right')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 17/17 [==============================] - 20s 897ms/step

# %% [markdown]
# ## Matriz de confusión

# %%
predicted_classes = np.argmax(predictions, axis=1)  # Obtener las clases predichas

# Graficar la matriz de confusión
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.4)  # Aumentar el tamaño de la fuente para la matriz de confusión
sns.heatmap(confusion_matrix(true_classes, predicted_classes), annot=True, fmt='d', cmap='Blues',
            xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.show()

# %%
# Crear un DataFrame para las predicciones y las clases verdaderas
pred_df = pd.DataFrame({
    'True Class': [class_labels[i] for i in true_classes],
    'Predicted Class': [class_labels[i] for i in predicted_classes]
})
pred_df['Correct'] = pred_df['True Class'] == pred_df['Predicted Class']
pred_df['Correct'] = pred_df['Correct'].map({True: 'Correct', False: 'Incorrect'})

# Graficar las predicciones
plt.figure(figsize=(10, 5))
sns.countplot(data=pred_df, x='Predicted Class', hue='Correct')
plt.title('Predictions vs True Classes')
plt.xlabel('Predicted Class')
plt.ylabel('Count')
plt.legend(title='Correctness')
plt.show()

# Graficar el reporte de clasificación
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Graficar el reporte de clasificación como un heatmap
report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
report_df = pd.DataFrame(report).transpose()
plt.figure(figsize=(10, 6))
sns.heatmap(report_df.iloc[:-1, :].T, annot=True, cmap='Blues', fmt='.2f')
plt.title('Classification Report Heatmap')
plt.xlabel('Metrics')
plt.ylabel('Classes')
plt.show()

# macro avg y weighted avg son promedios de las métricas para todas las clases
# macro avg: Promedio simple de las métricas para todas las clases (sin ponderar por el número de
# instancias)
# weighted avg: Promedio ponderado por el número de instancias en cada clase (más representativo si hay
# clases desbalanceadas)
# Out:
#               precision    recall  f1-score   support
#
#         AFIB       0.85      0.81      0.83       442
#         GSVT       0.87      0.90      0.89       459
#           SB       0.93      0.97      0.95       771
#           SR       0.89      0.83      0.86       443
#
#     accuracy                           0.89      2115
#    macro avg       0.89      0.88      0.88      2115
# weighted avg       0.89      0.89      0.89      2115
